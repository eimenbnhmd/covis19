# %%
#import relevant libraries

import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio

# %%
#Define plot styling

pio.templates.default = "plotly_dark"

# %%
#import "Our World in Data" Covid-19 dataset from github
df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/573cbdbefefeb331a414e7922988871a4cbfadd3/public/data/owid-covid-data.csv')

# %%
#create column for total case mortality

df["mortality"] = df["total_deaths"]/df["total_cases"]

# %%
#remove missing values from the columns of interest

df = df.dropna(subset=['people_fully_vaccinated_per_hundred', 'mortality'])

# %%
#create dataframe which only contains data for Germany

select_germany = df.loc[df['location'] == 'Germany']

# %%
#calculate summary statistics for the "Germany dataframe"

select_germany.describe()

# %%
fig = px.scatter(select_germany, x="people_fully_vaccinated_per_hundred", y="mortality", trendline="ols", size="icu_patients", 
                 title="Covid-19 Mortality and Percentage of Fully Vaccinated Pop. in Germany",)

fig.update_layout(
    xaxis_title="Percentage of Fully Vaccinated Population",
    yaxis_title="Case Mortality Rate")

fig.add_annotation(x=32, y=0.025,
            text="Markers' size is determined by the total number of ICU patients. Larger markers = more ICU patients.", 
            showarrow=True,
            arrowhead=1)

fig.add_annotation(x=-0.5, y=0.022,
            text="26-12-2020", 
            showarrow=True,
            arrowhead=1)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="18449e5f-26a0-4c8b-a4bb-6c42222c8664" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18449e5f-26a0-4c8b-a4bb-6c42222c8664")) {
#                     Plotly.newPlot(
#                         '18449e5f-26a0-4c8b-a4bb-6c42222c8664',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "people_fully_vaccinated_per_hundred=%{x}<br>mortality=%{y}<br>icu_patients=%{marker.size}", "legendgroup": "", "marker": {"color": "#636efa", "size": [5562.0, 5600.0, 5649.0, 5647.0, 5638.0, 5604.0, 5724.0, 5761.0, 5744.0, 5671.0, 5572.0, 5492.0, 5486.0, 5414.0, 5320.0, 5288.0, 5230.0, 5185.0, 5126.0, 5074.0, 5015.0, 4972.0, 5005.0, 4947.0, 4835.0, 4787.0, 4769.0, 4657.0, 4624.0, 4620.0, 4571.0, 4501.0, 4438.0, 4376.0, 4351.0, 4346.0, 4322.0, 4263.0, 4222.0, 4178.0, 4072.0, 3965.0, 3932.0, 3956.0, 3847.0, 3738.0, 3675.0, 3551.0, 3485.0, 3424.0, 3436.0, 3354.0, 3248.0, 3178.0, 3121.0, 3081.0, 3056.0, 3058.0, 3037.0, 2956.0, 2899.0, 2848.0, 2826.0, 2840.0, 2869.0, 2855.0, 2823.0, 2814.0, 2765.0, 2755.0, 2787.0, 2865.0, 2785.0, 2736.0, 2758.0, 2755.0, 2719.0, 2773.0, 2833.0, 2852.0, 2859.0, 2895.0, 2951.0, 2958.0, 3056.0, 3150.0, 3168.0, 3207.0, 3261.0, 3333.0, 3390.0, 3455.0, 3571.0, 3599.0, 3680.0, 3730.0, 3850.0, 3917.0, 4060.0, 4164.0, 4357.0, 4443.0, 4477.0, 4515.0, 4535.0, 4585.0, 4662.0, 4692.0, 4680.0, 4684.0, 4740.0, 4786.0, 4844.0, 4932.0, 4968.0, 4988.0, 5050.0, 5054.0, 5025.0, 5052.0, 5120.0, 5064.0, 5046.0, 5033.0, 5024.0, 5009.0, 5028.0, 5007.0, 4954.0, 4839.0, 4766.0, 4672.0, 4607.0, 4583.0, 4582.0, 4460.0, 4374.0, 4255.0, 4179.0, 4090.0, 4065.0, 4015.0, 3877.0, 3707.0, 3593.0, 3473.0, 3358.0, 3303.0, 3234.0, 3179.0, 3000.0, 2836.0, 2702.0, 2594.0, 2517.0, 2451.0, 2289.0, 2148.0, 2035.0, 1969.0, 1896.0, 1853.0, 